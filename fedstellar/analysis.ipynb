# %%
import pandas as pd
import matplotlib

# %%
data_path = "data/wandb_export_2023-05-05T17_45_54.132+02_00.csv"
df = pd.read_csv(data_path)
df.head()
# Out:
#             Name adversarial_args.attacks  Test/Accuracy  Test/Loss  \
# 0  participant_0                No Attack         0.9790   0.117876
# 1  participant_2                No Attack         0.9825   0.077477
# 2  participant_3                No Attack         0.9930   0.033223
# 3  participant_1                No Attack         0.9735   0.133212
# 4  participant_4                No Attack         0.9890   0.063392
#
#              Hostname                                              Group  \
# 0  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 1  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 2  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 3  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 4  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
#
#    trainer/global_step  Round     State Notes  ... 127.0.0.1:46540  \
# 0                    0     10  finished     -  ...             NaN
# 1                    0     10  finished     -  ...             NaN
# 2                    0     10  finished     -  ...             NaN
# 3                    0     10  finished     -  ...             NaN
# 4                    0     10  finished     -  ...             NaN
#
#    127.0.0.1:46541 127.0.0.1:46542  127.0.0.1:46543  127.0.0.1:46544  \
# 0              NaN             NaN              NaN              NaN
# 1              NaN             NaN              NaN              NaN
# 2              NaN             NaN              NaN              NaN
# 3              NaN             NaN              NaN              NaN
# 4              NaN             NaN              NaN              NaN
#
#   127.0.0.1:46550  127.0.0.1:46551  127.0.0.1:46552  127.0.0.1:46553  \
# 0             NaN              NaN              NaN              NaN
# 1             NaN              NaN              NaN              NaN
# 2             NaN              NaN              NaN              NaN
# 3             NaN              NaN              NaN              NaN
# 4             NaN              NaN              NaN              NaN
#
#    127.0.0.1:46554
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 68 columns]

# %%
benign = df[df["adversarial_args.attacks"]=="No Attack"]
benign
# Out:
#              Name adversarial_args.attacks  Test/Accuracy  Test/Loss  \
# 0   participant_0                No Attack         0.9790   0.117876
# 1   participant_2                No Attack         0.9825   0.077477
# 2   participant_3                No Attack         0.9930   0.033223
# 3   participant_1                No Attack         0.9735   0.133212
# 4   participant_4                No Attack         0.9890   0.063392
# 5   participant_0                No Attack         0.9605   0.217486
# 6   participant_3                No Attack         0.9915   0.039231
# 7   participant_4                No Attack         0.9875   0.082886
# 8   participant_2                No Attack         0.9740   0.182479
# 9   participant_1                No Attack         0.9760   0.137444
# 10  participant_0                No Attack         0.9725   0.135514
# 11  participant_4                No Attack         0.9740   0.123191
# 12  participant_3                No Attack         0.9880   0.057496
# 13  participant_2                No Attack         0.9755   0.099665
# 14  participant_1                No Attack         0.9690   0.166320
# 15  participant_0                No Attack         0.9705   0.166196
# 16  participant_2                No Attack         0.9825   0.076467
# 17  participant_4                No Attack         0.9845   0.084705
# 18  participant_3                No Attack         0.9915   0.037471
# 19  participant_1                No Attack         0.9735   0.162161
# 20  participant_0                No Attack         0.9760   0.125358
# 21  participant_2                No Attack         0.9720   0.110225
# 22  participant_4                No Attack         0.9845   0.075587
# 23  participant_3                No Attack         0.9925   0.031371
# 24  participant_1                No Attack         0.9685   0.119772
# 25  participant_0                No Attack         0.9765   0.126076
# 26  participant_4                No Attack         0.9865   0.073440
# 27  participant_3                No Attack         0.9910   0.049250
# 28  participant_2                No Attack         0.9830   0.061006
# 29  participant_1                No Attack         0.9640   0.190975
# 30  participant_0                No Attack         0.9780   0.107489
# 31  participant_2                No Attack         0.9835   0.065037
# 32  participant_3                No Attack         0.9920   0.047508
# 33  participant_4                No Attack         0.9865   0.058183
# 34  participant_1                No Attack         0.9780   0.119727
# 35  participant_0                No Attack         0.9755   0.142332
# 36  participant_3                No Attack         0.9920   0.040916
# 37  participant_2                No Attack         0.9805   0.088676
# 38  participant_1                No Attack         0.9710   0.147359
# 39  participant_4                No Attack         0.9880   0.079623
# 40  participant_0                No Attack         0.9750   0.128236
# 41  participant_4                No Attack         0.9875   0.070129
# 42  participant_3                No Attack         0.9920   0.037552
# 43  participant_2                No Attack         0.9840   0.077890
# 44  participant_1                No Attack         0.9750   0.127321
# 45  participant_0                No Attack         0.9770   0.125009
# 46  participant_3                No Attack         0.9915   0.039505
# 47  participant_4                No Attack         0.9890   0.056671
# 48  participant_2                No Attack         0.9840   0.076859
# 49  participant_1                No Attack         0.9755   0.139716
#
#               Hostname                                              Group  \
# 0   some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 1   some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 2   some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 3   some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 4   some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 5   some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 6   some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 7   some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 8   some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 9   some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 10  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 11  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 12  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 13  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 14  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 15  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 16  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 17  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 18  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 19  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 20  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 21  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 22  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 23  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 24  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 25  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 26  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 27  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 28  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 29  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 30  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 31  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 32  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 33  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 34  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 35  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 36  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 37  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 38  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 39  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 40  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 41  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 42  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 43  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 44  some-mba.fritz.box  MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R...
# 45  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 46  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 47  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 48  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
# 49  some-mba.fritz.box  MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0...
#
#     trainer/global_step  Round     State Notes  ... 127.0.0.1:46540  \
# 0                     0     10  finished     -  ...             NaN
# 1                     0     10  finished     -  ...             NaN
# 2                     0     10  finished     -  ...             NaN
# 3                     0     10  finished     -  ...             NaN
# 4                     0     10  finished     -  ...             NaN
# 5                     0     10  finished     -  ...             NaN
# 6                     0     10  finished     -  ...             NaN
# 7                     0     10  finished     -  ...             NaN
# 8                     0     10  finished     -  ...             NaN
# 9                     0     10  finished     -  ...             NaN
# 10                    0     10  finished     -  ...             NaN
# 11                    0     10  finished     -  ...             NaN
# 12                    0     10  finished     -  ...             NaN
# 13                    0     10  finished     -  ...             NaN
# 14                    0     10  finished     -  ...             NaN
# 15                    0     10  finished     -  ...        1.000000
# 16                    0     10  finished     -  ...        0.801160
# 17                    0     10  finished     -  ...        0.811402
# 18                    0     10  finished     -  ...        0.781949
# 19                    0     10  finished     -  ...        0.804455
# 20                    0     10  finished     -  ...             NaN
# 21                    0     10  finished     -  ...             NaN
# 22                    0      8  finished     -  ...             NaN
# 23                    0     10  finished     -  ...             NaN
# 24                    0     10  finished     -  ...             NaN
# 25                    0     10  finished     -  ...             NaN
# 26                    0     10  finished     -  ...             NaN
# 27                    0     10  finished     -  ...             NaN
# 28                    0     10  finished     -  ...             NaN
# 29                    0     10  finished     -  ...             NaN
# 30                    0     10  finished     -  ...             NaN
# 31                    0     10  finished     -  ...             NaN
# 32                    0     10  finished     -  ...             NaN
# 33                    0     10  finished     -  ...             NaN
# 34                    0     10  finished     -  ...             NaN
# 35                    0     10  finished     -  ...             NaN
# 36                    0     10  finished     -  ...             NaN
# 37                    0     10  finished     -  ...             NaN
# 38                    0     10  finished     -  ...             NaN
# 39                    0     10  finished     -  ...             NaN
# 40                    0     10  finished     -  ...             NaN
# 41                    0     10  finished     -  ...             NaN
# 42                    0     10  finished     -  ...             NaN
# 43                    0     10  finished     -  ...             NaN
# 44                    0     10  finished     -  ...             NaN
# 45                    0     10  finished     -  ...             NaN
# 46                    0     10  finished     -  ...             NaN
# 47                    0     10  finished     -  ...             NaN
# 48                    0     10  finished     -  ...             NaN
# 49                    0     10  finished     -  ...             NaN
#
#     127.0.0.1:46541 127.0.0.1:46542  127.0.0.1:46543  127.0.0.1:46544  \
# 0               NaN             NaN              NaN              NaN
# 1               NaN             NaN              NaN              NaN
# 2               NaN             NaN              NaN              NaN
# 3               NaN             NaN              NaN              NaN
# 4               NaN             NaN              NaN              NaN
# 5               NaN             NaN              NaN              NaN
# 6               NaN             NaN              NaN              NaN
# 7               NaN             NaN              NaN              NaN
# 8               NaN             NaN              NaN              NaN
# 9               NaN             NaN              NaN              NaN
# 10              NaN             NaN              NaN              NaN
# 11              NaN             NaN              NaN              NaN
# 12              NaN             NaN              NaN              NaN
# 13              NaN             NaN              NaN              NaN
# 14              NaN             NaN              NaN              NaN
# 15         0.804455        0.801160         0.781949         0.913399
# 16         0.797200        1.000000         0.783013         0.907785
# 17         0.800436        0.799377         0.791980         1.000000
# 18         0.782733        0.783013         1.000000         0.898859
# 19         1.000000        0.797200         0.782733         0.909086
# 20              NaN             NaN              NaN              NaN
# 21              NaN             NaN              NaN              NaN
# 22              NaN             NaN              NaN              NaN
# 23              NaN             NaN              NaN              NaN
# 24              NaN             NaN              NaN              NaN
# 25              NaN             NaN              NaN              NaN
# 26              NaN             NaN              NaN              NaN
# 27              NaN             NaN              NaN              NaN
# 28              NaN             NaN              NaN              NaN
# 29              NaN             NaN              NaN              NaN
# 30              NaN             NaN              NaN              NaN
# 31              NaN             NaN              NaN              NaN
# 32              NaN             NaN              NaN              NaN
# 33              NaN             NaN              NaN              NaN
# 34              NaN             NaN              NaN              NaN
# 35              NaN             NaN              NaN              NaN
# 36              NaN             NaN              NaN              NaN
# 37              NaN             NaN              NaN              NaN
# 38              NaN             NaN              NaN              NaN
# 39              NaN             NaN              NaN              NaN
# 40              NaN             NaN              NaN              NaN
# 41              NaN             NaN              NaN              NaN
# 42              NaN             NaN              NaN              NaN
# 43              NaN             NaN              NaN              NaN
# 44              NaN             NaN              NaN              NaN
# 45              NaN             NaN              NaN              NaN
# 46              NaN             NaN              NaN              NaN
# 47              NaN             NaN              NaN              NaN
# 48              NaN             NaN              NaN              NaN
# 49              NaN             NaN              NaN              NaN
#
#    127.0.0.1:46550  127.0.0.1:46551  127.0.0.1:46552  127.0.0.1:46553  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
# 5         1.000000         0.806623         0.791231         0.809993
# 6         0.912277         0.793561         0.797606         1.000000
# 7         0.918478         0.807735         0.805213         0.810928
# 8         0.905808         0.796614         1.000000         0.797606
# 9              NaN         1.000000              NaN              NaN
# 10             NaN              NaN              NaN              NaN
# 11             NaN              NaN              NaN              NaN
# 12             NaN              NaN              NaN              NaN
# 13             NaN              NaN              NaN              NaN
# 14             NaN              NaN              NaN              NaN
# 15             NaN              NaN              NaN              NaN
# 16             NaN              NaN              NaN              NaN
# 17             NaN              NaN              NaN              NaN
# 18             NaN              NaN              NaN              NaN
# 19             NaN              NaN              NaN              NaN
# 20             NaN              NaN              NaN              NaN
# 21             NaN              NaN              NaN              NaN
# 22             NaN              NaN              NaN              NaN
# 23             NaN              NaN              NaN              NaN
# 24             NaN              NaN              NaN              NaN
# 25             NaN              NaN              NaN              NaN
# 26             NaN              NaN              NaN              NaN
# 27             NaN              NaN              NaN              NaN
# 28             NaN              NaN              NaN              NaN
# 29             NaN              NaN              NaN              NaN
# 30             NaN              NaN              NaN              NaN
# 31             NaN              NaN              NaN              NaN
# 32             NaN              NaN              NaN              NaN
# 33             NaN              NaN              NaN              NaN
# 34             NaN              NaN              NaN              NaN
# 35             NaN              NaN              NaN              NaN
# 36             NaN              NaN              NaN              NaN
# 37             NaN              NaN              NaN              NaN
# 38             NaN              NaN              NaN              NaN
# 39             NaN              NaN              NaN              NaN
# 40             NaN              NaN              NaN              NaN
# 41             NaN              NaN              NaN              NaN
# 42             NaN              NaN              NaN              NaN
# 43             NaN              NaN              NaN              NaN
# 44             NaN              NaN              NaN              NaN
# 45             NaN              NaN              NaN              NaN
# 46             NaN              NaN              NaN              NaN
# 47             NaN              NaN              NaN              NaN
# 48             NaN              NaN              NaN              NaN
# 49             NaN              NaN              NaN              NaN
#
#     127.0.0.1:46554
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5          0.815248
# 6          0.810928
# 7          1.000000
# 8          0.805213
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# 30              NaN
# 31              NaN
# 32              NaN
# 33              NaN
# 34              NaN
# 35              NaN
# 36              NaN
# 37              NaN
# 38              NaN
# 39              NaN
# 40              NaN
# 41              NaN
# 42              NaN
# 43              NaN
# 44              NaN
# 45              NaN
# 46              NaN
# 47              NaN
# 48              NaN
# 49              NaN
#
# [50 rows x 68 columns]

# %%
runs_benign = benign.groupby(["aggregator_args.algorithm", "Group"], group_keys=True).apply(lambda x: x)

# %%
runs_benign_test_acc = benign.groupby(["aggregator_args.algorithm", 'Group'], group_keys=True)["Test/Accuracy"].mean()
group_benign_test_acc = benign.groupby(["aggregator_args.algorithm"], group_keys=True)["Test/Accuracy"].mean()

print(runs_benign_test_acc)
print(group_benign_test_acc)
# Out:
# aggregator_args.algorithm  Group
# FedAvg                     MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0_gaussian_20230505_161336     0.9834
#                            MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0_gaussian_20230505_161949     0.9814
#                            MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0_gaussian_20230505_163218     0.9787
#                            MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0_gaussian_20230505_163838     0.9758
#                            MNIST_MLP_FedAvg_fully_NoAttack_False_N0-S0_R0_gaussian_20230505_171716     0.9834
# FlTrust                    MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R0_gaussian_20230505_161643    0.9827
#                            MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R0_gaussian_20230505_162255    0.9836
#                            MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R0_gaussian_20230505_162912    0.9802
#                            MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R0_gaussian_20230505_163527    0.9805
#                            MNIST_MLP_FlTrust_fully_NoAttack_False_N0-S0_R0_gaussian_20230505_164150    0.9779
# Name: Test/Accuracy, dtype: float64
# aggregator_args.algorithm
# FedAvg     0.98054
# FlTrust    0.98098
# Name: Test/Accuracy, dtype: float64

# %%
overview = pd.pivot_table(benign, index=["aggregator_args.algorithm", "Group"], values=["Test/Accuracy"], aggfunc = 'mean')
overview.unstack().transpose().boxplot(showmeans=True)
# Out:
# <Axes: >

# %%
data = overview[["aggregator_args.algorithm", "Test/Accuracy"]]
